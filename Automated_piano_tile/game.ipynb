# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import ImageGrab as IG  
import pyautogui as pag
import time

# %% [markdown]
# (240,370) (240,860)
# (900,370) (900,860)

# %%
ssc = IG.grab(bbox= (370,230,870,1000))
ssc = np.array(ssc)
plt.figure(figsize=(40,77))
plt.imshow(ssc)
plt.show()

# %%
def grab_screen(bbox=None):
    screenshot = IG.grab(bbox)
    screenshot = np.array(screenshot)
    screenshot = cv2.cvtColor(screenshot,cv2.COLOR_RGB2BGR)
    return screenshot

# %%
class tile:
    def __init__(self,path):
        image = cv2.imread(path)
        self.image = image
        self.height = image.shape[0]
        self.width = image.shape[1]
        self.location = None
        pass
    
    def match(self,screen_img):
        result = cv2.matchTemplate(screen_img, self.image, cv2.TM_CCOEFF_NORMED)
        min_value, max_value, min_loc, max_loc = cv2.minMaxLoc(result)
        top_left = max_loc
        print("minloc: ", min_loc)
        print("maxloc: ", max_loc)
        bottom_right = (max_loc[0]+self.width, max_loc[1]+self.height)
        if(max_value > 0.90) :
            self.location = (top_left,bottom_right)
            return True
        else:
            return False

# %%
start = tile('start.png')
tile = tile('black_tile.png')

# %%
while True:
    screen  = grab_screen()
    if start.match(screen):
        if start.location!=None:
            Top_left = (370,230)
            Bottom_right = (870,1000)
            break
# Out:
# minloc:  (1148, 496)
# maxloc:  (487, 543)

# %%
pag.leftClick(start.location[0][0],start.location[0][1])

# %%
from ast import main


while True:
    main_panal = grab_screen(bbox=(Top_left[0],Top_left[1],Bottom_right[0],Bottom_right[1]))
    if tile.match(main_panal):
        cv2.rectangle(main_panal,tile.location[0],tile.location[1],(0,0,255),2)
        # print(tile.location[0][0],tile.location[0][1])
        # pag.leqftClick(tile.location[0][0],tile.location[0][1])
        # pag.click(x=tile.location[0][0],y=tile.location[0][1])
    cv2.imshow("Screen",main_panal)
    if cv2.waitKey(1) == ord('q') :
        cv2.destroyAllWindows()
        break
# Out:
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
# minloc:  (0, 0)
# maxloc:  (0, 0)
